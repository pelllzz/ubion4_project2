# %%
# Plan B : 보고서 가져오기로 선회

import requests
import csv
import pandas as pd

# %%
crtfc_key = '6c9ae05f7527c416cd8575ad214e65b6f255b6f2'

url_json = "https://opendart.fss.or.kr/api/list.json"
url_xml = "https://opendart.fss.or.kr/api/list.json"

corp_code = '01133217'

# %%
corp_code_csv_open = open("../raw_data/api_test_get_stock.csv", "r")
corp_code_csv_read = csv.reader(corp_code_csv_open)

# %%
corp_list = []

for comp_row in corp_code_csv_read:
    comp_row[0] = comp_row[0].zfill(8)
    corp_list.append(comp_row)

# %%
corp_list

# 데이터프레임화 -> 다시 리스트 뽑고 -> 으악
# 공시 보고서에서 추출하는 방법도 찾아보고
# Out:
# [['00260985', '한빛네트', '36720', '20170630'],
#  ['00264529', '엔플렉스', '40130', '20170630'],
#  ['00358545', '동서정보기술', '55000', '20170630'],
#  ['00231567', '애드모바일', '32600', '20170630'],
#  ['00247939', '씨모스', '37600', '20170630'],
#  ['00359614', '리더컴', '56140', '20170630'],
#  ['00153551', '허메스홀딩스', '12400', '20170630'],
#  ['00344746', '유티엑스', '45880', '20170630'],
#  ['00261188', '글로포스트', '37830', '20170630'],
#  ['00268020', '쏠라엔텍', '30390', '20170630'],
#  ['00269287', '보홍', '41320', '20170630'],
#  ['00475286', '동북아1호선박투자회사', '78420', '20170630'],
#  ['00250775', '에듀아크', '46350', '20170630'],
#  ['00114321', '데코', '13650', '20170630'],
#  ['00191108', '엘앤씨피', '15390', '20170630'],
#  ['00167378', '희훈디앤지', '19640', '20170630'],
#  ['00225210', '퓨쳐인포넷', '58690', '20170630'],
#  ['00223346', '쓰리디넷', '35400', '20170630'],
#  ['00174129', '제일저축은행', '24100', '20170630'],
#  ['00114826', '제일창업투자', '26540', '20170630'],
#  ['00173333', '현대DSF', '16510', '20170630'],
# ...
