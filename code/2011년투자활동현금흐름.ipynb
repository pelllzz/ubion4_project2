# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./csv/2011년투자활동현금흐름.csv',encoding='cp949')
df
# Out:
#             회사명  거래소코드     회계년도  투자활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                   -1845332.0
# 1      (주)CMG제약  58820  2012/12                  -30286514.0
# 2      (주)CMG제약  58820  2013/12                   20988786.0
# 3      (주)CMG제약  58820  2014/12                  -13611109.0
# 4      (주)CMG제약  58820  2015/12                   -8670890.0
# ...         ...    ...      ...                          ...
# 15145   흥아해운(주)   3280  2015/12                    -808840.0
# 15146   흥아해운(주)   3280  2016/12                  -12882473.0
# 15147   흥아해운(주)   3280  2017/12                   -1879921.0
# 15148   흥아해운(주)   3280  2018/12                   85526078.0
# 15149   흥아해운(주)   3280  2019/12                  121010088.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)
# 0                         -1773162.0
# 1                        -30265984.0
# 2                         21135376.0
# 3                        -13611109.0
# 4                         -8670780.0
# ...

# %%
df.isna().sum()

# %%
# df = df.drop(columns=['투자활동 변화율','투자활동변화율(연결)'], axis=1)
# df

# %%
# for i in range(len(df)-1):
#     # 음수,음수 일때
#     if df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] < 0:
#         df.loc[i, '투자활동플마여부'] = 'minus'
#     # 음수,양수 일때
#     elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] < 0 and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0:
#         df.loc[i,'투자활동플마여부'] = 'plus'
#     # 양수,음수 일때
#     elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0 and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] < 0:
#         df.loc[i,'투자활동플마여부'] = 'plus'
#     # 양수,양수 일때
#     elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0 and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0:
#         df.loc[i,'투자활동플마여부'] = 'plus'
        
#     # 음수,음수 연결 일때
#     if df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] < 0:
#         df.loc[i,'투자활동플마여부(연결)'] = 'minus'
#     # 음수,양수 연결 일때
#     elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] < 0 and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0:
#         df.loc[i,'투자활동플마여부(연결)'] = 'plus'
#     # 양수,음수 연결 일때
#     elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0 and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] < 0:
#         df.loc[i,'투자활동플마여부(연결)'] = 'plus'
#     # 양수,양수 일때
#     elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0 and df.loc[i+1,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0:
#         df.loc[i,'투자활동플마여부(연결)'] = 'plus'
# df
# Out:
#             회사명  거래소코드     회계년도  투자활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                   -1845332.0
# 1      (주)CMG제약  58820  2012/12                  -30286514.0
# 2      (주)CMG제약  58820  2013/12                   20988786.0
# 3      (주)CMG제약  58820  2014/12                  -13611109.0
# 4      (주)CMG제약  58820  2015/12                   -8670890.0
# ...         ...    ...      ...                          ...
# 15145   흥아해운(주)   3280  2015/12                    -808840.0
# 15146   흥아해운(주)   3280  2016/12                  -12882473.0
# 15147   흥아해운(주)   3280  2017/12                   -1879921.0
# 15148   흥아해운(주)   3280  2018/12                   85526078.0
# 15149   흥아해운(주)   3280  2019/12                  121010088.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS연결)(천원) 투자활동플마여부 투자활동플마여부(연결)
# 0                         -1773162.0    minus        minus
# 1                        -30265984.0     plus         plus
# ...

# %%
for i in range(len(df)):
    if df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] < 0:
        df.loc[i, '투자활동플마여부'] = 'minus'
    elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0:
        df.loc[i, '투자활동플마여부'] = 'plus'
    
    if df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] < 0:
        df.loc[i, '투자활동플마여부(연결)'] = 'minus'
    elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0:
        df.loc[i, '투자활동플마여부(연결)'] = 'plus'
        
df
# Out:
#             회사명  거래소코드     회계년도  투자활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                   -1845332.0
# 1      (주)CMG제약  58820  2012/12                  -30286514.0
# 2      (주)CMG제약  58820  2013/12                   20988786.0
# 3      (주)CMG제약  58820  2014/12                  -13611109.0
# 4      (주)CMG제약  58820  2015/12                   -8670890.0
# ...         ...    ...      ...                          ...
# 15145   흥아해운(주)   3280  2015/12                    -808840.0
# 15146   흥아해운(주)   3280  2016/12                  -12882473.0
# 15147   흥아해운(주)   3280  2017/12                   -1879921.0
# 15148   흥아해운(주)   3280  2018/12                   85526078.0
# 15149   흥아해운(주)   3280  2019/12                  121010088.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS연결)(천원) 투자활동플마여부 투자활동플마여부(연결)
# 0                         -1773162.0    minus        minus
# 1                        -30265984.0    minus        minus
# ...

# %%
for i in range(len(df)-1):
    # 음수,음수 일때
    if df.loc[i,'투자활동플마여부'] == 'minus' and df.loc[i+1,'투자활동플마여부'] == 'minus':
        df.loc[i,'절대값'] = abs(df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'])
    # 음수, 음수 연결 일때
    if df.loc[i,'투자활동플마여부(연결)'] == 'minus' and df.loc[i+1,'투자활동플마여부(연결)'] == 'minus':
        df.loc[i,'절대값(연결)'] = abs(df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'])
df.head(10)
# Out:
#         회사명  거래소코드     회계년도  투자활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0  (주)CMG제약  58820  2011/12                   -1845332.0
# 1  (주)CMG제약  58820  2012/12                  -30286514.0
# 2  (주)CMG제약  58820  2013/12                   20988786.0
# 3  (주)CMG제약  58820  2014/12                  -13611109.0
# 4  (주)CMG제약  58820  2015/12                   -8670890.0
# 5  (주)CMG제약  58820  2016/12                  -56094458.0
# 6  (주)CMG제약  58820  2017/12                    -467123.0
# 7  (주)CMG제약  58820  2018/12                    8779219.0
# 8  (주)CMG제약  58820  2019/12                  -70595614.0
# 9  (주)DB하이텍    990  2011/12                  -26649125.0
#
#    투자활동으로 인한 현금흐름(*)(IFRS연결)(천원) 투자활동플마여부 투자활동플마여부(연결)         절대값     절대값(연결)
# 0                     -1773162.0    minus        minus   1845332.0   1773162.0
# 1                    -30265984.0    minus        minus         NaN         NaN
# 2                     21135376.0     plus         plus         NaN         NaN
# ...

# %%
for i in range(len(df)):
    if df.loc[i,'투자활동플마여부'] == 'minus' and df.loc[i-1,'투자활동플마여부'] == 'minus':
        df.
