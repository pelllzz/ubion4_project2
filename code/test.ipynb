# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/help.csv", thousands=",", encoding="CP949")
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head(3)
# Out:
#         회사명  거래소코드    회계년도  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원) 자본율(개별)  \
# 0  (주)CMG제약  58820  11-Dec          27549.0          18291.0   66.39
# 1  (주)CMG제약  58820  12-Dec          56989.0          31603.0   55.45
# 2  (주)CMG제약  58820  13-Dec          55962.0          49048.0   87.65
#
#    자산(*)(IFRS)(천원)(연결)  자본(*)(IFRS)(천원)(연결) 자본율(연결)
# 0              38200.0              14702.0   66.39
# 1              52992.0              28102.0   55.45
# 2              55913.0              48997.0   87.63

# %%
df.iloc[0][8]
# Out:
# '66.39'

# %%
# df.iloc[i][5]
# df.iloc[i][8]

# csv 한바퀴 돌립니다
for i in range(0,len(df)):
    # 컬럼들 순회합니다
        # 개별에 결측치가 없다면
        if not pd.isna(df.iloc[i][5]):
            # 연결에도 결측치가 없다면
            if not pd.isna(df.iloc[i][8]):
                # 연결삽입
                df.loc[i, "자본율"] = df.iloc[i][8]

            # 연결이 결측치라면
            else:
                #개별 값 삽입
                df.loc[i, "자본율"] = df.iloc[i][5]

        # 개별에 결측치가 있다면
        else:
            # 연결에 결측치가 없다면
            if not pd.isna(df.iloc[i][8]):
                # 연결 삽입
                df.loc[i, "자본율"] = df.iloc[i][8]

            # 둘 다 없으면 통과
            else:
                pass

# %%
df
# Out:
#            회사명  거래소코드    회계년도  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원) 자본율(개별)  \
# 0     (주)CMG제약  58820  11-Dec          27549.0          18291.0   66.39
# 1     (주)CMG제약  58820  12-Dec          56989.0          31603.0   55.45
# 2     (주)CMG제약  58820  13-Dec          55962.0          49048.0   87.65
# 3     (주)CMG제약  58820  14-Dec          58127.0          49067.0   84.41
# 4     (주)CMG제약  58820  15-Dec          56592.0          46873.0   82.83
# ...        ...    ...     ...              ...              ...     ...
# 6448   흥아해운(주)   3280  14-Dec         627805.0         153936.0   24.52
# 6449   흥아해운(주)   3280  15-Dec         771212.0         161825.0   20.98
# 6450   흥아해운(주)   3280  16-Dec         942587.0         183829.0    19.5
# 6451   흥아해운(주)   3280  17-Dec         834107.0         107615.0    12.9
# 6452   흥아해운(주)   3280  18-Dec         782787.0          56732.0    7.25
#
#       자산(*)(IFRS)(천원)(연결)  자본(*)(IFRS)(천원)(연결) 자본율(연결)    자본율
# ...

# %%
df_x = pd.read_csv("../raw_data/use/매출원가축소_Raw.csv", thousands=",", encoding="CP949")
df_x
# Out:
#            회사명   거래소코드    회계년도  매출액(수익)(*)(IFRS연결)(천원)  매출원가(*)(IFRS연결)(천원)  \
# 0     (주)CMG제약   58820  Dec-10              11350419.0            8217627.0
# 1     (주)CMG제약   58820  Dec-11              17751704.0           10325799.0
# 2     (주)DB하이텍     990  Dec-10             620043034.0          753813405.0
# 3     (주)DB하이텍     990  Dec-11             552216245.0          460440945.0
# 4      (주)ES큐브   50120  Dec-10              43887335.0           32966862.0
# ...        ...     ...     ...                     ...                  ...
# 3463     휴젤(주)  145020  Dec-11              16172746.0            2902997.0
# 3464   흥구석유(주)   24060  Dec-10                     NaN                  NaN
# 3465   흥구석유(주)   24060  Dec-11                     NaN                  NaN
# 3466   흥아해운(주)    3280  Dec-10             606760235.0          541958332.0
# 3467   흥아해운(주)    3280  Dec-11             684331764.0          666958137.0
#
#       매출액(수익)(*)(IFRS)(천원)  매출원가(*)(IFRS)(천원)
# ...
